# %% [markdown]
# <a href="https://colab.research.google.com/github/no6767/ai-data-science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ask the student to enter their name

# %%
name = input("What is your name?")
# Out:
# What is your name?d

# %%
scores = [85, 90, 95]
average = sum(scores)/len(scores)
print("Hello", name)
print("Your average score is:", average)
# Out:
# Hello d
# Your average score is: 90.0
